# %%
##  ---------------------------------- ##
##  SCENARIO-1  ##
##  ---------------------------------- ##
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/sample_data/food_delivery_time_data.csv')
sns.histplot(df['Delivery_Time_Minutes'], kde=True, color='blue', bins=5)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Q-1............
# -- Explain why the mean is a misleading measure of central tendency for this delivery time dataset.
# -> in this dataset, most of the del time is bet 25 to 30 min where some of are nearly 90 which is big number or we can say it as outliers.
# mean is that which include all values and affected by outliers so avg is very high or increase then actucal avg and if someone ask us or we have to predict for new value we can't predict perfectly from this.
#
#
# -- Which alternative measure would you recommend.
# -> rather than use mean ,the best thing oor alternative of this central of tendency like median which best cause it not affected by outliers as well and also both of them tell about center of data but median is better.
#
# --how does the concept of skewness justify your choice? Describe what the shape of the distribution looks like.
# -> as we can see by data where there are outliers or most of data is spread on one side and other small data spread is other side where we see in graph there is not balance in data which we define as skewness and here we also say median is greater than mean.
# ->shape is right skewed.there is skewness on right side more.

# %% [markdown]
# ## -------------------- ##
# ## SCENARIO-2 ##
# ## -------------------- ##
#
# Q-2......................
# =>Apply Bayes' theorem to calculate the probability that a flagged order is truly fraudulent. Clearly identify the prior probability, likelihood, and how you arrive at the posterior. Explain why the result might surprise a non-technical stakeholder.
# ->if we have 1000 of orders and 5% where 50 orders are fruad and 950 are not fraud.
# ->where 90% correctly model says fraud so in 50 orders,45 is fruad and 5 missed like model say not fruad.
# ->in 8% of time,model say it is fraud wheather it actual not fruad so 76 is not fruad but model say it is fraud.
# ->we have to find what is model genuinely say how much orders are fraud so we have two scenario where 45 and 76 both where model says it is fraud total is 121 but 76 is not actually right so we have probabilities of actual detection is 32.7% which is posterior(info take after updated).
# -prior prob is 5% which is info before we update it.
# -likelihood is tha proob which has total value which we have is 90%.
# false-positive rate is 8%.
# ->it is surprising for non-stakeholder beacuse our model is predict 90% but actucally 76 are wrong.

# %% [markdown]
# ## ------------------ ##
# ## SCENARIO-3 ##
# ## ------------------ ##
# Que-3.......
# =>Identify two distinct preprocessing problems in this dataset that are directly responsible for the large gap between training and test accuracy. For each problem, name the specific technique you would apply to fix it and explain the mechanism by which the unresolved issue causes overfitting.
# -- there is large gap bet accuracy of taining and testing data where also overfitting when accuracy gap is greater than 15% we can say by that model is overftting.
# problem:-1 there is missing values in this dataset which cause model to overfit by when model learn data it not properly learn that when it see missing data it not understand and keep it so it is problem.
# --using imputer method we can fill missing values using median which is best method cause it doesn't affect by outliers.
# problem:-2 there is columns which is payment method which are in categorical so we have to convert it into numerical data so use one-hot encoder to do it.

# %% [markdown]
# ## ------------------- ##
# ## SCENARIO-4 ##
# ## ------------------- ##
# Que-4......................
# =>Explain why overall accuracy is a misleading primary metric for this problem. Which model should the finance team adopt? Name the specific evaluation metric that best captures the finance team's concern, define it mathematically, and justify your model choice using that metric.
# -> there is 50000 orders and only 1%(500) orders are detected correctly and 49500 are not fruad.
# ->there are two model A and  B where 99.1 and 94% accuracy so not like that if 99.1% is better than 94% becuase model A is mistake 1% which is it not identify correctly and model B is identify 420 out of 500 whrer it mistake where fruad to say not fraud it is false negative rate so 80 orders not correctly identify.
# ->model B is identify 84% correct and 16 % misses so it is called recall which we use to remove false negative and use Model B is best.

# %% [markdown]
# ## -------------------- ##
# ## SCENARIO-5 ##
# ## -------------------- ##
# Que-5..............
# =>Compare K-Means and DBSCAN specifically for this use case. Recommend one algorithm and justify your choice based on the stated data characteristics. Then describe one meaningful limitation of your chosen algorithm that the marketing team should understand before acting on the segments.
# ->so we have 80000 customers and need to make  groups based on their order frequency, average spend, and preferred delivery window like fequency of customer like how he spend and order from that it groups them.
# ->K-mean is algorithm where we first say how many cluster to make we can define then it based on properties do groups and also we have on scenario that clusters around 3-4 which directly say k-mean is used.
# ->Dbscan is that we find density and min_samples to make clusters so it is not case which is best algo it based on data charachterstics and problem.
# ->also we have outliers but not that much so for that used k-mean bacuse when we have to find more outliers we use dbscan.

# %% [markdown]
# ## -------------- ##
# ## SCENARIO-6 ##
# ## -------------- ##
# Que-6...................
# =>Explain the purpose of applying PCA before K-Means in this scenario. Describe how PCA reduces dimensionality while retaining the most important variance in the data. What trade-off must you consciously make when deciding how many principal components to retain, and how would you use the explained variance ratio to guide that decision?
# ->PCA(principal components analysis) it is used when two columns liinearly correlated and we have very much features and we can't visualize more dimentions so we use this technique for feature extraction which reduce feature which are not important that much it reduce like 10d to 2 or 3d which more useful.
# ->when we have multicolinear column where their variance is same but we need variance at high to decide which feature select and pca do this like rotate axis and make variance high to easily select what is important.
# ->Keeping fewer principal components gives greater dimensionality reduction and easier visualization but may lose important information, while keeping more components preserves more information but reduces the benefits of dimensionality reduction.
